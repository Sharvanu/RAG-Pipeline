# %%
# !pip install -U
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Please enter your GROQ API key: ")
    print("Please set the GROQ_API_KEY environment variable.")
    exit(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2365451720.py in <cell line: 0>()
#       3
#       4 if "GROQ_API_KEY" not in os.environ:
# ----> 5     os.environ["GROQ_API_KEY"] = getpass.getpass("Please enter your GROQ API key: ")
#       6     print("Please set the GROQ_API_KEY environment variable.")
#       7     exit(1)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Doc Loader
# !pip install -U Langchain-community
from langchain.document_loaders import TextLoader
loader = TextLoader('Your_File_in_Drive')
documents = loader.load()

# %%
documents

# %%
import textwrap
def wrap_text_preserve_newlines(text, width=110):
  #split
  lines = text.split('\n')
  wrapped_lines = [textwrap.fill(line, width=width) for line in lines]
  wrapped_text = '\n'.join(wrapped_lines)

  return wrapped_lines

# %%
print(wrap_text_preserve_newlines(str(documents[0])))

# %%
# Text Splitter
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# %%
len(docs)

# %%
# !pip install faiss-gpu
# !pip install faiss-cpu

# %%
#embbeding a vector Database
from langchain.vectorstores import FAISS
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter

# Install necessary packages for embbeding if not already installed
# !pip installed -U langchain-huggingface sentence-transformers
# !pip install openai
# !pip install faiss-cpu

# Re-split documents to ensure docs is a list of Documents objects
# Assuming 'documents' and 'text_splitter' are defined from previous cells
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

#Initialize the embedding model
embedding = HuggingFaceEmbeddings(model_name="Name_of _huggingface_model/OpenAI")

#Create the FIASS vector store
db = FAISS.from_documents(docs, embeddings)

# %%
query = "Ask_some_question/Give_some_task"
search_results = db.similarity_search(query, k=10)

# %%
print(query)
